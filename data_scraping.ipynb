# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarjonovizzatillo36/computer-vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download("uzbek pilaf plov food",
                     limit=100,
                     output_dir="/content/pilaf_images",
                     adult_filter_off=True,
                     force_replace=False,
                     timeout=60
                     )
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 27 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://loghi-famosi.com/wp-content/uploads/2022/04/Microsoft-OneDrive-Logo.png
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://www.liblogo.com/img-logo/on7659o6bb-onedrive-logo-onedrive.png
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://1000logos.net/wp-content/uploads/2020/08/OneDrive-Logo-2014.png
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://marketing.globuscs.info/production/strapi/uploads/partner_logo_Microsoft_One_Drive_2f084b2184.svg
# [!] Issue getting: https://marketing.globuscs.info/production/strapi/uploads/partner_logo_Microsoft_One_Drive_2f084b2184.svg
# [!] Error:: Invalid image, not saving https://marketing.globuscs.info/production/strapi/uploads/partner_logo_Microsoft_One_Drive_2f084b2184.svg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)

# %%
import os

print("pilaf_images mavjudmi:", os.path.exists('/content/pilaf_images'))
print("Papka ichidagilar:", os.listdir('/content/pilaf_images') if os.path.exists('/content/pilaf_images') else "yo'q")

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
print("source_dir mavjudmi:", os.path.exists(source_dir))
if os.path.exists(source_dir):
    print("Fayllar soni:", len(os.listdir(source_dir)))
# Out:
# pilaf_images mavjudmi: True
# Papka ichidagilar: ['uzbek pilaf plov food']
# source_dir mavjudmi: True
# Fayllar soni: 0

# %%
import os

target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'
print("target_dir mavjudmi:", os.path.exists(target_dir))
if os.path.exists(target_dir):
    print("Fayllar soni:", len(os.listdir(target_dir)))
    print("Birinchi 5 ta fayl:", os.listdir(target_dir)[:5])
# Out:
# target_dir mavjudmi: True
# Fayllar soni: 100
# Birinchi 5 ta fayl: ['Image_93.jpg', 'Image_64.jpg', 'Image_22.jpg', 'Image_47.jpg', 'Image_52.jpg']

# %%
downloader.download("kebab shashlik food",
                     limit=100,
                     output_dir='/content/kebab_images',
                     adult_filter_off=True,
                     force_replace=False,
                     timeout=60)
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 59 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.renegaderv.com/wp-content/uploads/2025/07/Renegade-RV-2026-Valencia-Class-C-Motorhome-34-Front-1200x800-1.png
# [!] Issue getting: https://www.renegaderv.com/wp-content/uploads/2025/07/Renegade-RV-2026-Valencia-Class-C-Motorhome-34-Front-1200x800-1.png
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from https://d1rmmjq3mtoxz0.cloudfront.net/uploads/images/126-M76022-202311110354400.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://r.cdn.autotraderspecialty.com/2020-Thor-Majestic-Motorhomes--Rv-300512896-3de4c4a1901f8191e33aac6263caa7a3.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://midtownrv.b-cdn.net/wp-content/uploads/2023/06/13756A-ft.jpg
# [%] File Downloaded!
#
# ...

# %%
import os, shutil

source_dir = '/content/kebab_images/kebab shashlik food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_file = os.path.join(target_dir, filename)
    shutil.move(src_file, dst_file)
