# %% [markdown]
# <a href="https://colab.research.google.com/github/akbarjonovizzatillo36/computer-vision/blob/main/menu_detector_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Menu Detector!')
# Out:
# Menu Detector!

# %%
# ----------------------------------------
# Import Libraries
# ----------------------------------------
from google.colab import drive
import torchvision.transforms as transforms

from PIL import Image, UnidentifiedImageError
from torch.utils.data import Dataset
import os
import numpy as np

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define Dataset Path

DATASET_PATH = '/content/drive/MyDrive/food101_dataset'
print('Dataset_path:', DATASET_PATH)


CUSTOM_CLASS_MAPPING = {
    "hamburger": "hamburger",
    "hot_dog": "hot_dog",
    "chocolate_cake": "dessert",  # label grouping | class consolidation
    "cheesecake": "dessert",      # label grouping | class consolidation
    "kebab": "kebab",
    "pilaf": "pilaf"
}


CLASSES = ['hamburger', 'hot_dog', 'dessert', 'kebab', 'pilaf']
CLASS_TO_IDX = {cls: i for i, cls in enumerate(CLASSES)}
NUM_CLASSES = len(CLASSES)

print(NUM_CLASSES)
print(CLASS_TO_IDX)

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
# Out:
# Dataset_path: /content/drive/MyDrive/food101_dataset
# 5
# {'hamburger': 0, 'hot_dog': 1, 'dessert': 2, 'kebab': 3, 'pilaf': 4}

# %%
# ----------------------------------------
# Custom Dataset Class
# ----------------------------------------

class FoodDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        print('images_length', len(self.images))
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        print('image_path', img_path)
        label = self.labels[idx]
        print('label', label)
        try:
            image = Image.open(img_path).convert('RGB')
        except (UnidentifiedImageError, OSError):
            print(f"Skipping broken image: {img_path}")
            return self.__getitem__((idx + 1) % len(self.images))
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# ----------------------------------------
# Gather and Split Data
# ----------------------------------------
all_images = []
for original_class, mapped_class in CUSTOM_CLASS_MAPPING.items():
    class_path = os.path.join(DATASET_PATH, original_class) # /content/drive/MyDrive/food101_dataset/hamburger
    print('class_path:', class_path)
    if not os.path.exists(class_path):
        print(f"Warning: {class_path} not found")
        continue
    for img in os.listdir(class_path):
        if img.endswith(('.jpg', '.jpeg', '.png')): # .txt, .docx
            full_path = os.path.join(class_path, img) # /content/drive/MyDrive/food101_dataset/hamburger/100057.jpg
            all_images.append((full_path, CLASS_TO_IDX[mapped_class]))

np.random.shuffle(all_images)
split = int(0.8 * len(all_images))
train_data = all_images[:split] # 1000 | 800 train_data | 200 val_data
val_data = all_images[split:]

train_images, train_labels = zip(*train_data)
val_images, val_labels = zip(*val_data)

# print('all_images:', all_images)

dataset = FoodDataset(train_images, train_labels)
print(len(dataset))
img, lbl = dataset[0]
# Out:
# class_path: /content/drive/MyDrive/food101_dataset/hamburger
# class_path: /content/drive/MyDrive/food101_dataset/hot_dog
# Warning: /content/drive/MyDrive/food101_dataset/hot_dog not found
# class_path: /content/drive/MyDrive/food101_dataset/chocolate_cake
# class_path: /content/drive/MyDrive/food101_dataset/cheesecake
# class_path: /content/drive/MyDrive/food101_dataset/kebab
# class_path: /content/drive/MyDrive/food101_dataset/pilaf
# all_images: [('/content/drive/MyDrive/food101_dataset/hamburger/842229.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hamburger/90115.jpg', 0), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3773956.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1460596.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/529616.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3356764.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/2135938.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hamburger/3816451.jpg', 0), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/445014.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/1488723.jpg', 0), ('/content/drive/MyDrive/food101_dataset/cheesecake/1955517.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1439060.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/2953772.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1061232.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1159749.jpg', 2), ('/content/drive/MyDrive/food101_dataset/kebab/Image_85.jpg', 3), ('/content/drive/MyDrive/food101_dataset/cheesecake/2850292.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/1822493.jpg', 0), ('/content/drive/MyDrive/food101_dataset/cheesecake/90021.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1325564.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2185089.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/129939.jpg', 0), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1902144.jpg', 2), ('/content/drive/MyDrive/food101_dataset/kebab/Image_34.jpg', 3), ('/content/drive/MyDrive/food101_dataset/hamburger/1170104.jpg', 0), ('/content/drive/MyDrive/food101_dataset/cheesecake/2928889.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/120612.jpg', 0), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3005657.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2584547.jpg', 2), ('/content/drive/MyDrive/food101_dataset/kebab/Image_24.jpg', 3), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3121457.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/1923778.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/3210837.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2899046.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3160967.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/1741383.jpg', 0), ('/content/drive/MyDrive/food101_dataset/hamburger/100517.jpg', 0), ('/content/drive/MyDrive/food101_dataset/cheesecake/882135.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/878103.jpg', 0), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2054690.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2339620.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/2214528.jpg', 0), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3417862.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3707840.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/2047998.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/3115914.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/750008.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/969644.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/1864488.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/3038291.jpg', 2), ('/content/drive/MyDrive/food101_dataset/cheesecake/2439835.jpg', 2), ('/content/drive/MyDrive/food101_dataset/kebab/Image_11.jpg', 3), ('/content/drive/MyDrive/food101_dataset/pilaf/Image_42.jpg', 4), ('/content/drive/MyDrive/food101_dataset/cheesecake/3845030.jpg', 2), ('/content/drive/MyDrive/food101_dataset/chocolate_cake/2217188.jpg', 2), ('/content/drive/MyDrive/food101_dataset/hamburger/3162373.jpg', 0), ('/content/drive/MyDrive/food10 ...
# images_length 2556
# 2556
# image_path /content/drive/MyDrive/food101_dataset/hamburger/842229.jpg
# label 0
